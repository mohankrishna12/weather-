# %%
import requests

def weather_agent(city: str):
    """
    Fetch real-time weather data for a given city
    """
    API_KEY = "e31dfd1ff6b676bbbd78903d3d0e7305"
    url = (
        "https://api.openweathermap.org/data/2.5/weather"
        f"?q={city}&appid={API_KEY}&units=metric"
    )

    response = requests.get(url)
    return response.json()

# %%
data = weather_agent("Hyderabad")
data
# Out:
# {'cod': 401,
#  'message': 'Invalid API key. Please see https://openweathermap.org/faq#error401 for more info.'}

# %%
data = weather_agent("Hyderabad")
data
# Out:
# {'coord': {'lon': 78.4744, 'lat': 17.3753},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01n'}],
#  'base': 'stations',
#  'main': {'temp': 19.24,
#   'feels_like': 18.55,
#   'temp_min': 19.24,
#   'temp_max': 19.24,
#   'pressure': 1017,
#   'humidity': 51,
#   'sea_level': 1017,
#   'grnd_level': 953},
#  'visibility': 10000,
#  'wind': {'speed': 2.48, 'deg': 64, 'gust': 3.47},
#  'clouds': {'all': 1},
#  'dt': 1767636544,
#  'sys': {'country': 'IN', 'sunrise': 1767575840, 'sunset': 1767615896},
#  'timezone': 19800,
#  'id': 1269843,
#  'name': 'Hyderabad',
#  'cod': 200}
